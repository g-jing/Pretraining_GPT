# %%
import json
from pytorch_transformers import GPT2Tokenizer

# %%
with open("trainListFile.json", "r") as f:
    train_list = f.readlines()
    train_list = [item.strip() for item in train_list]

with open("valListFile.json", "r") as f:
    val_list = f.readlines()
    val_list = [item.strip() for item in val_list]

with open("testListFile.json", "r") as f:
    test_list = f.readlines()
    test_list = [item.strip() for item in test_list]
    
with open("data_for_sequicity_new_ptr.json", "r") as f:
    all_data = json.load(f)

# %%
def retrieve_list(file_list):
    data = []
    for file in train_list:
        try:
            data.append(all_data[file.lower()[:-5]])
        except:
            print(file.lower()[:-5], "not found")
            
    return data

# %%
train_data = retrieve_list(train_list)
val_data = retrieve_list(val_list)
test_data = retrieve_list(test_list)
# Out:
# pmul2245 not found
# pmul4776 not found
# pmul3872 not found
# pmul4859 not found
# pmul2245 not found
# pmul4776 not found
# pmul3872 not found
# pmul4859 not found
# pmul2245 not found
# pmul4776 not found
# pmul3872 not found
# pmul4859 not found

# %%
with open("train_data.json", "w") as f:
    json.dump(train_data, f, indents=4)
    
with open("val_data.json", "w") as f:
    json.dump(val_data, f, indents=4)
    
with open("test_data.json", "w") as f:
    json.dump(test_data, f, indents=4)

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# %%
tokenizer.tokenize("general")
# Out:
# ['general']

# %%
test_list
# Out:
# ['MUL0484.json',
#  'PMUL4462.json',
#  'PMUL0320.json',
#  'MUL2155.json',
#  'PMUL0815.json',
#  'PMUL3263.json',
#  'PMUL3672.json',
#  'SNG0423.json',
#  'SNG0296.json',
#  'PMUL0079.json',
#  'PMUL1484.json',
#  'SNG0840.json',
#  'PMUL0089.json',
#  'PMUL2859.json',
#  'PMUL2009.json',
#  'SNG0528.json',
#  'SNG01367.json',
#  'PMUL3858.json',
#  'SNG1076.json',
#  'PMUL2166.json',
#  'PMUL2436.json',
#  'MUL0225.json',
#  'PMUL1966.json',
#  'PMUL4239.json',
#  'SNG01290.json',
#  'SNG0888.json',
#  'SNG1150.json',
#  'MUL2646.json',
#  'PMUL4247.json',
#  'SNG0589.json',
#  'MUL2089.json',
#  'SNG01434.json',
#  'MUL0237.json',
#  'PMUL4125.json',
#  'MUL1588.json',
#  'MUL0432.json',
#  'SNG0253.json',
#  'PMUL4998.json',
#  'PMUL1323.json',
#  'SNG0580.json',
#  'PMUL2719.json',
#  'PMUL3224.json',
#  'PMUL4440.json',
#  'PMUL4840.json',
#  'SNG0081.json',
#  'SNG02172.json',
#  'PMUL0550.json',
#  'PMUL3558.json',
#  'PMUL2275.json',
#  'PMUL3600.json',
#  'SNG0323.json',
#  'MUL0323.json',
#  'MUL1137.json',
#  'MUL2525.json',
#  'MUL0409.json',
#  'SNG01359.json',
#  'PMUL1259.json',
#  'SNG0568.json',
#  'PMUL1374.json',
#  'SNG02315.json',
#  'PMUL3437.json',
#  'MUL0454.json',
#  'MUL1926.json',
#  'PMUL1180.json',
#  'MUL0744.json',
#  'SNG1004.json',
#  'PMUL1412.json',
#  'PMUL0998.json',
#  'PMUL4660.json',
#  'SNG0006.json',
#  'PMUL1755.json',
#  'PMUL0399.json',
#  'PMUL3921.json',
#  'MUL1848.json',
#  'SNG0085.json',
#  'SNG02205.json',
#  'PMUL4880.json',
#  'SNG01153.json',
#  'MUL0537.json',
#  'MUL1555.json',
#  'PMUL0844.json',
#  'PMUL4025.json',
#  'SNG0691.json',
#  'PMUL1002.json',
#  'PMUL4949.json',
#  'MUL1248.json',
#  'MUL1008.json',
#  'PMUL1455.json',
#  'SNG0416.json',
#  'MUL0978.json',
#  'MUL0524.json',
#  'PMUL2953.json',
#  'SNG0832.json',
#  'PMUL4643.json',
#  'PMUL4716.json',
#  'MUL0071.json',
#  'SNG0317.json',
#  'PMUL1477.json',
#  'PMUL1424.json',
#  'PMUL4693.json',
#  'MUL2499.json',
#  'MUL1575.json',
#  'PMUL1173.json',
#  'PMUL1385.json',
#  'PMUL1463.json',
#  'PMUL3309.json',
#  'PMUL0578.json',
#  'PMUL2477.json',
#  'SNG0390.json',
#  'MUL2120.json',
#  'MUL0671.json',
#  'PMUL1320.json',
#  'MUL2410.json',
#  'MUL0197.json',
#  'MUL1811.json',
#  'MUL2269.json',
#  'MUL2053.json',
#  'MUL2146.json',
#  'PMUL2503.json',
#  'MUL0842.json',
#  'MUL1695.json',
#  'PMUL2210.json',
#  'MUL0869.json',
#  'MUL2138.json',
#  'MUL0264.json',
#  'SNG01884.json',
#  'SNG01432.json',
#  'MUL0391.json',
#  'MUL1285.json',
#  'MUL2368.json',
#  'SNG0451.json',
#  'PMUL2636.json',
#  'PMUL3027.json',
#  'PMUL0509.json',
#  'PMUL3044.json',
#  'PMUL1920.json',
#  'PMUL3141.json',
#  'MUL2042.json',
#  'MUL1050.json',
#  'MUL1598.json',
#  'PMUL2634.json',
#  'PMUL1867.json',
#  'MUL0677.json',
#  'PMUL4134.json',
#  'PMUL1266.json',
#  'SNG02153.json',
#  'PMUL2272.json',
#  'MUL1489.json',
#  'PMUL0129.json',
#  'PMUL1978.json',
#  'SNG0571.json',
#  'SNG01608.json',
#  'MUL0496.json',
#  'PMUL1763.json',
#  'MUL1202.json',
#  'MUL0397.json',
#  'PMUL1210.json',
#  'PMUL0573.json',
#  'SNG01353.json',
#  'PMUL1931.json',
#  'SNG0927.json',
#  'PMUL1344.json',
#  'PMUL1788.json',
#  'PMUL1329.json',
#  'SNG01503.json',
#  'PMUL2917.json',
#  'SNG01634.json',
#  'PMUL0566.json',
#  'PMUL3599.json',
#  'MUL2206.json',
#  'SNG0940.json',
#  'PMUL2330.json',
#  'MUL2106.json',
#  'PMUL3424.json',
#  'SNG0733.json',
#  'MUL2365.json',
#  'MUL1569.json',
#  'PMUL1593.json',
#  'PMUL4186.json',
#  'PMUL0006.json',
#  'MUL2442.json',
#  'SNG01692.json',
#  'MUL2130.json',
#  'MUL2193.json',
#  'MUL1661.json',
#  'SNG0617.json',
#  'PMUL1623.json',
#  'PMUL2006.json',
#  'PMUL4368.json',
#  'PMUL1801.json',
#  'SNG0098.json',
#  'PMUL3279.json',
#  'MUL2321.json',
#  'MUL2305.json',
#  'PMUL2882.json',
#  'MUL0798.json',
#  'MUL1627.json',
#  'MUL0073.json',
#  'PMUL4231.json',
#  'PMUL4616.json',
#  'MUL1697.json',
#  'PMUL4842.json',
#  'PMUL0090.json',
#  'PMUL1812.json',
#  'PMUL0713.json',
#  'SNG0456.json',
#  'MUL2569.json',
#  'PMUL2563.json',
#  'MUL1514.json',
#  'SNG0722.json',
#  'MUL2423.json',
#  'MUL1491.json',
#  'PMUL2746.json',
#  'MUL2218.json',
#  'SNG0613.json',
#  'MUL1060.json',
#  'MUL1527.json',
#  'SNG0455.json',
#  'MUL2270.json',
#  'MUL1552.json',
#  'PMUL0919.json',
#  'MUL1376.json',
#  'MUL2294.json',
#  'MUL1649.json',
#  'PMUL0367.json',
#  'PMUL3647.json',
#  'PMUL1462.json',
#  'PMUL1316.json',
#  'PMUL0410.json',
#  'PMUL0864.json',
#  'PMUL1772.json',
#  'MUL0937.json',
#  'PMUL0832.json',
#  'PMUL4317.json',
#  'MUL0814.json',
#  'MUL0148.json',
#  'MUL0260.json',
#  'MUL2664.json',
#  'SNG1042.json',
#  'PMUL4964.json',
#  'PMUL2194.json',
#  'PMUL4048.json',
#  'MUL1110.json',
#  'MUL0785.json',
#  'SNG0008.json',
#  'PMUL1182.json',
#  'MUL2116.json',
#  'PMUL4567.json',
#  'PMUL0204.json',
#  'MUL0354.json',
#  'MUL0018.json',
#  'SNG0095.json',
#  'MUL1045.json',
#  'MUL1883.json',
#  'MUL1958.json',
#  'SNG0792.json',
#  'MUL1515.json',
#  'MUL1633.json',
#  'MUL1935.json',
#  'PMUL3933.json',
#  'PMUL2491.json',
#  'MUL0474.json',
#  'PMUL3778.json',
#  'SNG01403.json',
#  'SNG0715.json',
#  'PMUL4155.json',
#  'PMUL4026.json',
#  'MUL1028.json',
#  'MUL0364.json',
#  'PMUL3734.json',
#  'MUL0089.json',
#  'SNG01936.json',
#  'PMUL3992.json',
#  'MUL1899.json',
#  'PMUL3012.json',
#  'MUL2195.json',
#  'MUL2072.json',
#  'MUL1642.json',
#  'SNG01542.json',
#  'PMUL0692.json',
#  'MUL2275.json',
#  'PMUL0109.json',
#  'PMUL2119.json',
#  'MUL0370.json',
#  'PMUL4077.json',
#  'MUL0466.json',
#  'MUL0212.json',
#  'PMUL2627.json',
#  'PMUL2215.json',
#  'MUL2320.json',
#  'MUL1675.json',
#  'MUL0457.json',
#  'SNG0519.json',
#  'PMUL3304.json',
#  'MUL0233.json',
#  'PMUL1253.json',
#  'MUL0810.json',
#  'SNG0274.json',
#  'PMUL2670.json',
#  'SNG02096.json',
#  'PMUL4255.json',
#  'MUL2439.json',
#  'MUL1612.json',
#  'SNG01775.json',
#  'MUL2281.json',
#  'PMUL3310.json',
#  'MUL0088.json',
#  'SNG0308.json',
#  'PMUL0548.json',
#  'PMUL3803.json',
#  'PMUL3759.json',
#  'SNG01270.json',
#  'PMUL4610.json',
#  'PMUL4946.json',
#  'MUL0690.json',
#  'PMUL3336.json',
#  'MUL2427.json',
#  'PMUL1613.json',
#  'PMUL1067.json',
#  'SNG0354.json',
#  'SNG0692.json',
#  'MUL0844.json',
#  'MUL1620.json',
#  'MUL1351.json',
#  'MUL1803.json',
#  'SNG01937.json',
#  'SNG0735.json',
#  'MUL0035.json',
#  'PMUL4059.json',
#  'SNG0073.json',
#  'MUL1806.json',
#  'MUL1254.json',
#  'MUL0789.json',
#  'MUL1554.json',
#  'PMUL1533.json',
#  'PMUL4229.json',
#  'SNG01262.json',
#  'SNG0466.json',
#  'PMUL4294.json',
#  'MUL2119.json',
#  'MUL0624.json',
#  'PMUL3625.json',
#  'MUL0498.json',
#  'SNG0482.json',
#  'PMUL4603.json',
#  'PMUL1113.json',
#  'PMUL2195.json',
#  'PMUL1949.json',
#  'PMUL3264.json',
#  'MUL1289.json',
#  'SNG02006.json',
#  'MUL0208.json',
#  'MUL0340.json',
#  'MUL0072.json',
#  'SNG0539.json',
#  'SNG01835.json',
#  'MUL2012.json',
#  'MUL1015.json',
#  'PMUL3737.json',
#  'PMUL4325.json',
#  'MUL2466.json',
#  'MUL0371.json',
#  'MUL0469.json',
#  'PMUL0795.json',
#  'MUL0003.json',
#  'SNG0799.json',
#  'MUL0881.json',
#  'SNG01710.json',
#  'PMUL3940.json',
#  'MUL0510.json',
#  'MUL0621.json',
#  'PMUL0012.json',
#  'SNG0659.json',
#  'MUL0230.json',
#  'SNG0767.json',
#  'MUL0528.json',
#  'PMUL1118.json',
#  'MUL2284.json',
#  'MUL0388.json',
#  'SNG0016.json',
#  'SNG1041.json',
#  'SNG0305.json',
#  'PMUL2513.json',
#  'PMUL3834.json',
#  'MUL0841.json',
#  'MUL0912.json',
#  'MUL0450.json',
#  'PMUL1470.json',
#  'PMUL4622.json',
#  'MUL2001.json',
#  'PMUL1183.json',
#  'PMUL0685.json',
#  'SNG1105.json',
#  'PMUL4542.json',
#  'MUL1189.json',
#  'PMUL2146.json',
#  'SNG0256.json',
#  'PMUL1526.json',
#  'PMUL2403.json',
#  'MUL0555.json',
#  'MUL0772.json',
#  'PMUL1172.json',
#  'PMUL4366.json',
#  'SNG01534.json',
#  'MUL0803.json',
#  'PMUL0267.json',
#  'SNG1075.json',
#  'PMUL4001.json',
#  'PMUL1869.json',
#  'SNG0055.json',
#  'PMUL2945.json',
#  'MUL1064.json',
#  'MUL0628.json',
#  'MUL0116.json',
#  'PMUL1537.json',
#  'PMUL1046.json',
#  'MUL0992.json',
#  'MUL1422.json',
#  'MUL0346.json',
#  'PMUL1087.json',
#  'SNG0933.json',
#  'PMUL4644.json',
#  'PMUL3913.json',
#  'PMUL3919.json',
#  'MUL1392.json',
#  'PMUL1844.json',
#  'MUL1596.json',
#  'MUL1478.json',
#  'PMUL2279.json',
#  'SNG0644.json',
#  'PMUL4648.json',
#  'PMUL4122.json',
#  'SNG0391.json',
#  'MUL1836.json',
#  'MUL0822.json',
#  'MUL1211.json',
#  'PMUL3145.json',
#  'PMUL4626.json',
#  'PMUL2437.json',
#  'SNG0721.json',
#  'PMUL1283.json',
#  'PMUL3723.json',
#  'PMUL2457.json',
#  'MUL2491.json',
#  'MUL0738.json',
#  'MUL1076.json',
#  'MUL2609.json',
#  'SNG0964.json',
#  'MUL0638.json',
#  'SNG01492.json',
#  'PMUL4259.json',
#  'PMUL3066.json',
#  'PMUL1809.json',
#  'MUL2376.json',
#  'MUL1753.json',
#  'PMUL0265.json',
#  'MUL1024.json',
#  'SNG01733.json',
#  'MUL1274.json',
#  'PMUL4905.json',
#  'MUL1159.json',
#  'MUL0080.json',
#  'PMUL4140.json',
#  'SNG0078.json',
#  'MUL0843.json',
#  'MUL2567.json',
#  'PMUL2703.json',
#  'SNG01767.json',
#  'PMUL1373.json',
#  'PMUL3815.json',
#  'PMUL0875.json',
#  'PMUL4672.json',
#  'PMUL2778.json',
#  'PMUL3495.json',
#  'MUL2139.json',
#  'PMUL3156.json',
#  'SNG0004.json',
#  'PMUL1521.json',
#  'MUL1638.json',
#  'PMUL0982.json',
#  'MUL2386.json',
#  'PMUL2123.json',
#  'MUL1350.json',
#  'SNG0293.json',
#  'PMUL1105.json',
#  'SNG02018.json',
#  'MUL1212.json',
#  'SNG01332.json',
#  'PMUL1148.json',
#  'SNG0483.json',
#  'PMUL3890.json',
#  'PMUL4356.json',
#  'PMUL3162.json',
#  'SNG01679.json',
#  'MUL2542.json',
#  'PMUL3494.json',
#  'MUL2151.json',
#  'PMUL3239.json',
#  'PMUL3742.json',
#  'PMUL1895.json',
#  'PMUL4362.json',
#  'SNG0781.json',
#  'SNG01538.json',
#  'PMUL1486.json',
#  'PMUL2174.json',
#  'PMUL0095.json',
#  'MUL0316.json',
#  'PMUL2708.json',
#  'SNG0897.json',
#  'PMUL3247.json',
#  'PMUL3523.json',
#  'MUL2359.json',
#  'PMUL3520.json',
#  'MUL2060.json',
#  'MUL2358.json',
#  'PMUL0069.json',
#  'PMUL2869.json',
#  'SNG0661.json',
#  'MUL1838.json',
#  'MUL0831.json',
#  'MUL2405.json',
#  'PMUL0117.json',
#  'PMUL0182.json',
#  'MUL1493.json',
#  'MUL0890.json',
#  'SNG01165.json',
#  'SNG0690.json',
#  'PMUL3423.json',
#  'PMUL4258.json',
#  'MUL0369.json',
#  'MUL0838.json',
#  'SNG1066.json',
#  'PMUL1435.json',
#  'SNG1078.json',
#  'PMUL3957.json',
#  'MUL1240.json',
#  'MUL0947.json',
#  'MUL1606.json',
#  'MUL0594.json',
#  'PMUL1854.json',
#  'SNG0830.json',
#  'PMUL3301.json',
#  'PMUL2286.json',
#  'SNG0898.json',
#  'MUL0682.json',
#  'MUL0990.json',
#  'PMUL4731.json',
#  'SNG01323.json',
#  'SNG0515.json',
#  'SNG1086.json',
#  'SNG01898.json',
#  'PMUL4034.json',
#  'PMUL4504.json',
#  'SNG0678.json',
#  'PMUL2983.json',
#  'SNG0954.json',
#  'MUL2051.json',
#  'PMUL0615.json',
#  'MUL0383.json',
#  'MUL1455.json',
#  'PMUL4054.json',
#  'SNG0892.json',
#  'PMUL3171.json',
#  'PMUL4713.json',
#  'SNG01272.json',
#  'MUL0011.json',
#  'SNG01530.json',
#  'MUL1870.json',
#  'PMUL3946.json',
#  'MUL1828.json',
#  'SNG01686.json',
#  'PMUL1811.json',
#  'MUL2665.json',
#  'SNG0689.json',
#  'PMUL0994.json',
#  'MUL1624.json',
#  'PMUL3328.json',
#  'PMUL1987.json',
#  'MUL1091.json',
#  'MUL0570.json',
#  'PMUL3731.json',
#  'PMUL1944.json',
#  'PMUL0558.json',
#  'PMUL1332.json',
#  'MUL1766.json',
#  'MUL1066.json',
#  'PMUL3668.json',
#  'MUL2086.json',
#  'MUL0760.json',
#  'PMUL3785.json',
#  'SNG0874.json',
#  'PMUL1330.json',
#  'PMUL2980.json',
#  'PMUL0599.json',
#  'MUL0379.json',
#  'SNG01386.json',
#  'PMUL2452.json',
#  'PMUL0745.json',
#  'SNG01943.json',
#  'MUL0761.json',
#  'PMUL2558.json',
#  'MUL0222.json',
#  'PMUL1247.json',
#  'PMUL4515.json',
#  'PMUL3376.json',
#  'PMUL1241.json',
#  'PMUL1136.json',
#  'PMUL0899.json',
#  'MUL1258.json',
#  'SNG0994.json',
#  'PMUL3918.json',
#  'PMUL2483.json',
#  'MUL0286.json',
#  'PMUL3439.json',
#  'PMUL3107.json',
#  'SNG01673.json',
#  'MUL1860.json',
#  'PMUL2704.json',
#  'PMUL1983.json',
#  'SNG0586.json',
#  'MUL1410.json',
#  'SNG0867.json',
#  'MUL1746.json',
#  'MUL2290.json',
#  'PMUL1853.json',
#  'MUL2162.json',
#  'PMUL4131.json',
#  'SNG0412.json',
#  'MUL1692.json',
#  'SNG02240.json',
#  'SNG0742.json',
#  'PMUL1347.json',
#  'SNG01873.json',
#  'SNG0991.json',
#  'PMUL3897.json',
#  'MUL1855.json',
#  'MUL2657.json',
#  'PMUL4011.json',
#  'MUL1342.json',
#  'MUL1986.json',
#  'MUL2137.json',
#  'SNG02198.json',
#  'MUL1739.json',
#  'MUL0309.json',
#  'PMUL1600.json',
#  'MUL2630.json',
#  'SNG0007.json',
#  'SNG0908.json',
#  'PMUL0630.json',
#  'MUL2074.json',
#  'SNG0610.json',
#  'PMUL4343.json',
#  'PMUL2205.json',
#  'MUL1712.json',
#  'PMUL1804.json',
#  'MUL0014.json',
#  'MUL0341.json',
#  'MUL1657.json',
#  'PMUL4641.json',
#  'MUL1077.json',
#  'PMUL4106.json',
#  'MUL0473.json',
#  'PMUL1981.json',
#  'PMUL3283.json',
#  'PMUL3085.json',
#  'MUL1192.json',
#  'PMUL2000.json',
#  'SNG0855.json',
#  'SNG1048.json',
#  'MUL0099.json',
#  'PMUL4306.json',
#  'MUL0941.json',
#  'MUL2317.json',
#  'PMUL4318.json',
#  'SNG01983.json',
#  'PMUL2497.json',
#  'MUL1787.json',
#  'SNG0518.json',
#  'PMUL3976.json',
#  'MUL1466.json',
#  'MUL0845.json',
#  'PMUL4524.json',
#  'PMUL0782.json',
#  'SNG1126.json',
#  'MUL0492.json',
#  'PMUL4432.json',
#  'SNG0338.json',
#  'PMUL2848.json',
#  'MUL1560.json',
#  'MUL0739.json',
#  'MUL1763.json',
#  'PMUL4078.json',
#  'PMUL1657.json',
#  'PMUL1109.json',
#  'SNG01755.json',
#  'MUL0332.json',
#  'MUL0113.json',
#  'MUL1800.json',
#  'PMUL4819.json',
#  'PMUL1779.json',
#  'MUL2432.json',
#  'SNG02207.json',
#  'MUL2658.json',
#  'MUL2099.json',
#  'PMUL0674.json',
#  'MUL1983.json',
#  'MUL1071.json',
#  'PMUL3160.json',
#  'PMUL4044.json',
#  'SNG0280.json',
#  'MUL1664.json',
#  'PMUL3868.json',
#  'SNG0429.json',
#  'PMUL3886.json',
#  'PMUL2756.json',
#  'SNG0701.json',
#  'SNG0755.json',
#  'MUL2225.json',
#  'SNG01907.json',
#  'MUL1833.json',
#  'PMUL3662.json',
#  'PMUL0938.json',
#  'MUL0669.json',
#  'SNG1090.json',
#  'MUL0533.json',
#  'MUL1799.json',
#  'PMUL4636.json',
#  'PMUL2755.json',
#  'SNG01919.json',
#  'PMUL4326.json',
#  'PMUL1273.json',
#  'PMUL1311.json',
#  'PMUL4780.json',
#  'SNG01924.json',
#  'PMUL3127.json',
#  'PMUL3514.json',
#  'SNG0572.json',
#  'MUL2063.json',
#  'PMUL3907.json',
#  'MUL1417.json',
#  'PMUL0441.json',
#  'SNG01683.json',
#  'MUL2122.json',
#  'PMUL1998.json',
#  'SNG0468.json',
#  'MUL0787.json',
#  'SNG1026.json',
#  'MUL2347.json',
#  'PMUL3685.json',
#  'PMUL3275.json',
#  'PMUL0522.json',
#  'PMUL1834.json',
#  'PMUL1232.json',
#  'PMUL1980.json',
#  'MUL2378.json',
#  'PMUL2380.json',
#  'MUL0654.json',
#  'SNG0649.json',
#  'PMUL4800.json',
#  'PMUL3126.json',
#  'PMUL2209.json',
#  'SNG0322.json',
#  'MUL1650.json',
#  'MUL1088.json',
#  'MUL0939.json',
#  'SNG0772.json',
#  'SNG0446.json',
#  'PMUL3748.json',
#  'SNG0611.json',
#  'MUL2204.json',
#  'SNG01155.json',
#  'PMUL4756.json',
#  'PMUL3576.json',
#  'SNG0005.json',
#  'MUL1759.json',
#  'PMUL4958.json',
#  'SNG0547.json',
#  'PMUL4333.json',
#  'SNG0805.json',
#  'MUL2148.json',
#  'PMUL0205.json',
#  'MUL0575.json',
#  'PMUL1256.json',
#  'SNG0477.json',
#  'MUL1901.json',
#  'PMUL3557.json',
#  'PMUL3506.json',
#  'PMUL2898.json',
#  'PMUL4941.json',
#  'PMUL3875.json',
#  'MUL0373.json',
#  'PMUL3465.json',
#  'PMUL0457.json',
#  'MUL0828.json',
#  'MUL0034.json',
#  'MUL2415.json',
#  'SNG01752.json',
#  'PMUL3348.json',
#  'MUL1268.json',
#  'PMUL1284.json',
#  'SNG01797.json',
#  'MUL2457.json',
#  'PMUL3014.json',
#  'MUL1818.json',
#  'MUL1055.json',
#  'MUL1505.json',
#  'MUL0374.json',
#  'MUL2177.json',
#  'PMUL1982.json',
#  'PMUL1420.json',
#  'PMUL4383.json',
#  'PMUL0076.json',
#  'MUL0389.json',
#  'SNG01380.json',
#  'MUL0353.json',
#  'PMUL4388.json',
#  'PMUL1739.json',
#  'PMUL1200.json',
#  'PMUL1276.json',
#  'PMUL0506.json',
#  'PMUL3364.json',
#  'PMUL3425.json',
#  'PMUL2311.json',
#  'MUL0821.json',
#  'PMUL3549.json',
#  'SNG1036.json',
#  'SNG01850.json',
#  'SNG0529.json',
#  'PMUL3663.json',
#  'PMUL3415.json',
#  'PMUL2729.json',
#  'PMUL4911.json',
#  'MUL2686.json',
#  'MUL1228.json',
#  'SNG0983.json',
#  'PMUL1775.json',
#  'SNG0099.json',
#  'PMUL4050.json',
#  'SNG0348.json',
#  'MUL0172.json',
#  'SNG02202.json',
#  'SNG01551.json',
#  'SNG0941.json',
#  'MUL0021.json',
#  'SNG1012.json',
#  'PMUL3521.json',
#  'MUL0901.json',
#  'PMUL1762.json',
#  'MUL2482.json',
#  'MUL0228.json',
#  'MUL0818.json',
#  'SNG0779.json',
#  'MUL0515.json',
#  'PMUL3707.json',
#  'SNG0590.json',
#  'PMUL3596.json',
#  'SNG0797.json',
#  'PMUL4357.json',
#  'PMUL4605.json',
#  'PMUL4303.json',
#  'SNG0069.json',
#  'PMUL0518.json',
#  'MUL2197.json',
#  'PMUL2239.json',
#  'MUL2675.json',
#  'PMUL1883.json',
#  'PMUL2578.json',
#  'MUL1059.json',
#  'PMUL1137.json',
#  'SNG0284.json',
#  'SNG0500.json',
#  'MUL2637.json',
#  'PMUL4234.json',
#  'SNG0600.json',
#  'MUL2009.json',
#  'PMUL0873.json',
#  'MUL0239.json',
#  'SNG0962.json',
#  'PMUL2351.json',
#  'MUL1365.json',
#  'MUL2316.json',
#  'PMUL1036.json',
#  'MUL1117.json',
#  'SNG02319.json',
#  'PMUL4884.json',
#  'PMUL4316.json',
#  'SNG0714.json',
#  'PMUL0048.json',
#  'PMUL3649.json',
#  'SNG0979.json',
#  'MUL1139.json',
#  'MUL2077.json',
#  'PMUL4894.json',
#  'PMUL0286.json',
#  'SNG0782.json',
#  'SNG0448.json',
#  'SNG0531.json',
#  'MUL0896.json',
#  'SNG0345.json',
#  'SNG0061.json',
#  'SNG01940.json',
#  'MUL1276.json',
#  'SNG0822.json',
#  'PMUL4547.json',
#  'SNG0768.json',
#  'MUL1278.json',
#  'MUL0540.json',
#  'PMUL4569.json',
#  'MUL0004.json',
#  'MUL0694.json',
#  'SNG0775.json',
#  'PMUL3158.json',
#  'SNG1016.json',
#  'SNG01784.json',
#  'MUL2523.json',
#  'SNG0289.json',
#  'MUL0536.json',
#  'PMUL2080.json',
#  'PMUL3935.json',
#  'PMUL1370.json',
#  'SNG0459.json',
#  'MUL0144.json',
#  'MUL2301.json',
#  'PMUL0262.json',
#  'PMUL4176.json',
#  'MUL1273.json',
#  'SNG1147.json',
#  'PMUL1952.json',
#  'MUL1475.json',
#  'MUL0613.json',
#  'SNG0866.json',
#  'SNG01366.json',
#  'PMUL3403.json',
#  'PMUL3293.json',
#  'PMUL2433.json',
#  'PMUL2933.json',
#  'SNG0360.json',
#  'MUL0352.json',
#  'PMUL4220.json',
#  'SNG0616.json',
#  'PMUL3708.json',
#  'MUL1690.json',
#  'PMUL0768.json',
#  'PMUL2489.json',
#  'PMUL4224.json',
#  'PMUL2124.json',
#  'MUL1508.json',
#  'PMUL1106.json',
#  'SNG0636.json',
#  'MUL1756.json',
#  'PMUL3688.json',
#  'PMUL1147.json',
#  'PMUL1091.json',
#  'PMUL3217.json',
#  'PMUL0276.json',
#  'MUL1678.json',
#  'SNG0263.json',
#  'SNG01391.json',
#  'PMUL4246.json',
#  'SNG01819.json',
#  'PMUL3931.json',
#  'SNG0803.json',
#  'SNG02342.json',
#  'MUL0849.json',
#  'PMUL3282.json',
#  'PMUL4564.json',
#  'PMUL0732.json',
#  'SNG1091.json',
#  'PMUL1359.json',
#  'MUL1122.json',
#  'MUL1546.json',
#  'MUL0198.json',
#  'PMUL4930.json',
#  'PMUL2362.json',
#  'PMUL1008.json',
#  'PMUL4919.json',
#  'MUL1718.json',
#  'PMUL1342.json',
#  'MUL1898.json',
#  'PMUL4344.json',
#  'MUL1418.json',
#  'SNG0681.json',
#  'SNG0433.json',
#  'SNG0471.json',
#  'MUL1844.json',
#  'SNG1070.json',
#  'SNG01957.json',
#  'MUL1607.json',
#  'MUL0199.json',
#  'MUL0297.json',
#  'PMUL2942.json',
#  'SNG0601.json',
#  'MUL1981.json',
#  'SNG0527.json',
#  'MUL2254.json',
#  'MUL0306.json',
#  'MUL2228.json',
#  'MUL0641.json',
#  'PMUL1194.json',
#  'MUL0527.json']
